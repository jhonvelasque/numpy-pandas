# %%
import numpy as np
import pandas as pd

# %%
df1=pd.read_excel('./respaldo.xls',sheet_name='Personas',header=0,)

# %%
df=pd.read_excel('./respaldo.xls',sheet_name='Compras',header= 0)

# %%
db
# Out:
#                  Años           2018
# 0                 NaN            NaN
# 1    Cuenta de Ventas            NaN
# 2         País/Región          Total
# 3           Argentina             44
# 4            Barbados              4
# ..                ...            ...
# 72  15015.66-20015.66   1353748.0884
# 73  20015.66-25015.66    1155061.132
# 74  25015.66-30015.66      513728.88
# 75  30015.66-35015.66      419369.12
# 76      Total general  21568048.6404
#
# [77 rows x 2 columns]

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [Id. de la fila, Id. del pedido, Fecha del pedido, Fecha de envío, Forma de envío, Id. del cliente, Nombre del cliente, Segmento, Ciudad, Estado, País/Región, Región, Id. del producto, Categoría, Subcategoría, Nombre del producto, Ventas, Cantidad, Descuento, Ganancia]
# Index: []

# %%
df.loc[:,['Ventas']]>1000
# Out:
#        Ventas
# 0       False
# 1        True
# 2       False
# 3       False
# 4        True
# ...       ...
# 10249   False
# 10250    True
# 10251   False
# 10252   False
# 10253   False
#
# [10254 rows x 1 columns]

# %%
df.iloc[:]
# Out:
#        Id. de la fila  Id. del pedido Fecha del pedido Fecha de envío  \
# 0                1682  MX-2021-111899       2021-04-02     2021-04-06
# 1                5919  MX-2021-113922       2021-10-08     2021-10-11
# 2                5920  MX-2021-113922       2021-10-08     2021-10-11
# 3                9013  MX-2019-163888       2019-06-14     2019-06-18
# 4                9014  MX-2019-163888       2019-06-14     2019-06-18
# ...               ...             ...              ...            ...
# 10249            9786  US-2019-126284       2019-10-16     2019-10-22
# 10250            9787  US-2019-126284       2019-10-16     2019-10-22
# 10251            9788  US-2019-126284       2019-10-16     2019-10-22
# 10252            9789  US-2019-126284       2019-10-16     2019-10-22
# 10253            9790  US-2019-126284       2019-10-16     2019-10-22
#
#       Forma de envío Id. del cliente  Nombre del cliente         Segmento  \
# ...

# %%
df.iloc[400,16]
# Out:
# 1432.6400000000003

# %%
df.drop('Subcategoría',axis=1).head(2)
# Out:
#    Id. de la fila  Id. del pedido Fecha del pedido Fecha de envío  \
# 0            1682  MX-2021-111899       2021-04-02     2021-04-06
# 1            5919  MX-2021-113922       2021-10-08     2021-10-11
#
#   Forma de envío Id. del cliente  Nombre del cliente Segmento  \
# 0       Estándar        AM-11365  Araceli Manzanares  Empresa
# 1         Rápido        BS-12130   Benjamín Saavedra  Cliente
#
#             Ciudad Estado País/Región Región Id. del producto  \
# 0  Cruzeiro do Sul   Acre      Brasil    Sur  MAT-AR-10004857
# 1       Rio Branco   Acre      Brasil    Sur  MOB-LI-10000647
#
#              Categoría                   Nombre del producto  Ventas  \
# 0  Material de oficina  Boston Rotuladores, Tamaños variados   591.0
# 1           Mobiliario     Dania Conjunto de estantes, Metal  2250.8
#
#    Cantidad  Descuento  Ganancia
# 0         3        0.0     206.4
# 1         2        0.0     922.8

# %%
df
# Out:
#        Id. de la fila  Id. del pedido Fecha del pedido Fecha de envío  \
# 0                1682  MX-2021-111899       2021-04-02     2021-04-06
# 1                5919  MX-2021-113922       2021-10-08     2021-10-11
# 2                5920  MX-2021-113922       2021-10-08     2021-10-11
# 3                9013  MX-2019-163888       2019-06-14     2019-06-18
# 4                9014  MX-2019-163888       2019-06-14     2019-06-18
# ...               ...             ...              ...            ...
# 10249            9786  US-2019-126284       2019-10-16     2019-10-22
# 10250            9787  US-2019-126284       2019-10-16     2019-10-22
# 10251            9788  US-2019-126284       2019-10-16     2019-10-22
# 10252            9789  US-2019-126284       2019-10-16     2019-10-22
# 10253            9790  US-2019-126284       2019-10-16     2019-10-22
#
#       Forma de envío Id. del cliente  Nombre del cliente         Segmento  \
# ...

# %%
rango=df['Ventas'].max()-df['Ventas'].min()

# %%
rango
# Out:
# 34725.14

# %%
df.iloc[[0],:]
# Out:
#    Id. de la fila  Id. del pedido Fecha del pedido Fecha de envío  \
# 0            1682  MX-2021-111899       2021-04-02     2021-04-06
#
#   Forma de envío Id. del cliente  Nombre del cliente Segmento  \
# 0       Estándar        AM-11365  Araceli Manzanares  Empresa
#
#             Ciudad Estado País/Región Región Id. del producto  \
# 0  Cruzeiro do Sul   Acre      Brasil    Sur  MAT-AR-10004857
#
#              Categoría Subcategoría                   Nombre del producto  \
# 0  Material de oficina         Arte  Boston Rotuladores, Tamaños variados
#
#    Ventas  Cantidad  Descuento  Ganancia
# 0   591.0         3        0.0     206.4

# %%
df[(df['País/Región'] =='Brasil') & (df['Cantidad']>4)]
# Out:
#       Id. de la fila  Id. del pedido Fecha del pedido Fecha de envío  \
# 2               5920  MX-2021-113922       2021-10-08     2021-10-11
# 8               3315  MX-2018-141726       2018-11-11     2018-11-16
# 10              3499  MX-2020-166443       2020-08-21     2020-08-25
# 21              8064  MX-2021-113586       2021-11-18     2021-11-18
# 33             10056  US-2018-149041       2018-06-01     2018-06-06
# ...              ...             ...              ...            ...
# 9517            1090  MX-2021-150868       2021-10-15     2021-10-15
# 9518            1091  MX-2021-150868       2021-10-15     2021-10-15
# 9870            1405  MX-2020-152996       2020-01-20     2020-01-27
# 9873            1408  MX-2020-152996       2020-01-20     2020-01-27
# 9874            3350  MX-2021-142356       2021-11-21     2021-11-22
#
#      Forma de envío Id. del cliente Nombre del cliente         Segmento  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10254 entries, 0 to 10253
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id. de la fila       10254 non-null  int64
#  1   Id. del pedido       10254 non-null  object
#  2   Fecha del pedido     10254 non-null  datetime64[ns]
#  3   Fecha de envío       10254 non-null  datetime64[ns]
#  4   Forma de envío       10254 non-null  object
#  5   Id. del cliente      10254 non-null  object
#  6   Nombre del cliente   10254 non-null  object
#  7   Segmento             10254 non-null  object
#  8   Ciudad               10254 non-null  object
#  9   Estado               10254 non-null  object
#  10  País/Región          10254 non-null  object
#  11  Región               10254 non-null  object
#  12  Id. del producto     10254 non-null  object
#  13  Categoría            10254 non-null  object
#  14  Subcategoría         10254 non-null  object
# ...

# %%
df.describe()
# Out:
#        Id. de la fila        Ventas      Cantidad     Descuento      Ganancia
# count    10254.000000  10254.000000  10254.000000  10254.000000  10254.000000
# mean      5146.149308   2103.379037      3.740492      0.135709    214.737238
# std       2970.876591   3491.494504      2.199333      0.195662   1189.617598
# min          1.000000     15.660000      1.000000      0.000000 -18062.400000
# 25%       2574.250000    328.800000      2.000000      0.000000     -7.740000
# 50%       5146.500000    803.960000      3.000000      0.000000     80.000000
# 75%       7718.750000   2277.900000      5.000000      0.400000    325.800000
# max      10288.000000  34740.800000     14.000000      0.800000  13132.800000

# %%
df.memory_usage(deep=True)
# Out:
# Index                     128
# Id. de la fila          82032
# Id. del pedido         728034
# Fecha del pedido        82032
# Fecha de envío          82032
# Forma de envío         872202
# Id. del cliente        671934
# Nombre del cliente     824718
# Segmento               717440
# Ciudad                 756022
# Estado                 776487
# País/Región            762855
# Región                 634413
# Id. del producto       741504
# Categoría              788670
# Subcategoría           713857
# Nombre del producto    957395
# Ventas                  82032
# Cantidad                82032
# Descuento               82032
# Ganancia                82032
# dtype: int64

# %%
df.groupby('País/Región').count().iloc[2:6,2:4]
# Out:
#              Fecha del pedido  Fecha de envío
# País/Región
# Bolivia                    48              48
# Brasil                   1593            1593
# Chile                     143             143
# Colombia                  360             360

# %%
ganancia=df.groupby('País/Región').sum().reset_index()
# Out:
# C:\Users\jhon.velasque\AppData\Local\Temp\ipykernel_19020\3651171805.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   ganancia=df.groupby('País/Región').sum().reset_index()

# %%
df['gananciap']=df['Ganancia'].apply(lambda x :abs(x))

# %%
df
# Out:
#        Id. de la fila  Id. del pedido Fecha del pedido Fecha de envío  \
# 0                1682  MX-2021-111899       2021-04-02     2021-04-06
# 1                5919  MX-2021-113922       2021-10-08     2021-10-11
# 2                5920  MX-2021-113922       2021-10-08     2021-10-11
# 3                9013  MX-2019-163888       2019-06-14     2019-06-18
# 4                9014  MX-2019-163888       2019-06-14     2019-06-18
# ...               ...             ...              ...            ...
# 10249            9786  US-2019-126284       2019-10-16     2019-10-22
# 10250            9787  US-2019-126284       2019-10-16     2019-10-22
# 10251            9788  US-2019-126284       2019-10-16     2019-10-22
# 10252            9789  US-2019-126284       2019-10-16     2019-10-22
# 10253            9790  US-2019-126284       2019-10-16     2019-10-22
#
#       Forma de envío Id. del cliente  Nombre del cliente         Segmento  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10254 entries, 0 to 10253
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id. de la fila       10254 non-null  int64
#  1   Id. del pedido       10254 non-null  object
#  2   Fecha del pedido     10254 non-null  datetime64[ns]
#  3   Fecha de envío       10254 non-null  datetime64[ns]
#  4   Forma de envío       10254 non-null  object
#  5   Id. del cliente      10254 non-null  object
#  6   Nombre del cliente   10254 non-null  object
#  7   Segmento             10254 non-null  object
#  8   Ciudad               10254 non-null  object
#  9   Estado               10254 non-null  object
#  10  País/Región          10254 non-null  object
#  11  Región               10254 non-null  object
#  12  Id. del producto     10254 non-null  object
#  13  Categoría            10254 non-null  object
#  14  Subcategoría         10254 non-null  object
# ...

# %%
df['Ventas'].sum()
# Out:
# 21568048.640399996

# %%
df.groupby('País/Región').agg({'Ventas':['min','max']})
# Out:
#                       Ventas
#                          min       max
# País/Región
# Argentina              15.66  23006.16
# Barbados               68.40  18381.00
# Bolivia                57.20  14018.40
# Brasil                 22.72  34080.00
# Chile                  52.00  24235.40
# Colombia               31.80  31721.40
# Cuba                   31.80  28180.80
# Ecuador                43.20  22868.80
# El Salvador            31.80  29687.00
# Guatemala              57.60  31170.88
# Haití                  32.64  10914.12
# Honduras               23.64  21802.44
# Jamaica                71.20  13809.00
# México                 38.60  34740.80
# Nicaragua              41.00  27972.48
# Panamá                 31.80  15645.60
# Paraguay              192.40   8200.80
# Perú                   31.44   9869.04
# República Dominicana   35.52  23752.96
# Trinidad y Tobago     157.32  20764.80
# Uruguay                84.40  34731.40
# Venezuela              19.56  10540.20

# %%
from numpy.lib.index_tricks import index_exp


tablaunida=df.merge(df1,left_on='Región',right_on='Región').groupby('País/Región').min().reset_index()

# %%
tablaunida.sort_values('País/Región',ascending=False)
# Out:
#              País/Región  Id. de la fila  Id. del pedido Fecha del pedido  \
# 21             Venezuela             122  MX-2018-150385       2018-01-10
# 20               Uruguay             413  MX-2018-125227       2018-11-09
# 19     Trinidad y Tobago            2333  MX-2019-101035       2019-05-11
# 18  República Dominicana              41  MX-2018-105298       2018-01-15
# 17                  Perú              77  MX-2018-103331       2018-03-22
# 16              Paraguay            1001  MX-2018-167955       2018-06-04
# 15                Panamá              17  MX-2018-100195       2018-02-01
# 14             Nicaragua              12  MX-2018-100762       2018-01-14
# 13                México               1  MX-2018-100174       2018-01-04
# 12               Jamaica            1104  MX-2018-115686       2018-11-05
# 11              Honduras              28  MX-2018-117485       2018-03-04
# 10                 Haití             123  MX-2018-107993       2018-03-22
# ...

# %% [markdown]
# df.mer

# %% [markdown]
# ## Examen

# %%
import numpy as np

# %%
np.linspace(0,10,100)
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
arr = np.array([13, 6, 3, 5, 10])

# %%
arr[arr>7]
# Out:
# array([13, 10])

# %%
arr = np.array([13, 6, 3, 5, 10])

# %%
#devuelve el indice del mayor valor 
np.argmax(arr)
# Out:
# 0

# %%
print('hola mundo')
# Out:
# hola mundo
