# %% [markdown]
# # PANDAS

# %% [markdown]
# Pandas
# Pandas es una librería de Python especializada en el manejo y análisis de estructuras de datos. El nombre viene de “Panel data”.
#
# • Velocidad
# • Poco código
# • Múltiples formatos de archivos
# • Alineación inteligente
#
# Pandas Series
# Es muy parecido a un array de una dimensión (o vector) de NumPy.
#
# • Arreglo unidimensional indexado
# • Búsqueda por índice
# • Slicing
# • Operaciones aritméticas
# • Distintos tipos de datos
#
# Pandas DataFrame
# Muy parecido a las estructuras matriciales trabajadas con NumPy.
#
# • Estructura principal
# • Arreglo de dos dimensiones
# • Búsqueda por índice (columnas o filas)
# • Slicing
# • Operaciones aritméticas
# • Distintos tipos de datos
# • Tamaño variable

# %%
import pandas as pd

# %%
lit=pd.array([1,2,3,4])

# %%
print(lit)
# Out:
# <IntegerArray>
# [1, 2, 3, 4]
# Length: 4, dtype: Int64

# %%
player=pd.Series(['navas','messi','jhon','neymar'],index=[1,2,3,8],dtype='string')

# %%
enteros=pd.Series([1,2,5,6,7,8], index=['a','b','c','d','f','g'],dtype='string')

# %%
print(enteros)
# Out:
# a    1
# b    2
# c    5
# d    6
# f    7
# g    8
# dtype: string

# %%
bedroom={'calentador':'heater','cama':'bed','espejo':'mirror','silla':'chair','lampara':'lamp','sabana':'bed sheet','cortina':'curtain'}
cuarto=pd.Series(bedroom)

# %%
cuarto['sabana']
# Out:
# 'bed sheet'

# %%
cuarto['espejo':]
# Out:
# espejo        mirror
# silla          chair
# lampara         lamp
# sabana     bed sheet
# cortina      curtain
# dtype: object

# %%
enteros['a']
# Out:
# '1'

# %%
player[2:6]
# Out:
# C:\Users\jhon.velasque\AppData\Local\Temp\ipykernel_15604\53836529.py:1: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   player[2:6]
# 3      jhon
# 8    neymar
# dtype: string

# %%
peru={'jugador':['ladula','cueva','adbincula','carrillo','jhon'],
    'altura':[1.7,1.6,1.94,1.78,1.83],
    'goles':[4,45,100,456,123]}

# %%
dfJugadores=pd.DataFrame(peru,index=[1,2,3,4,5])

# %%
dfJugadores.index
# Out:
# Int64Index([1, 2, 3, 4, 5], dtype='int64')

# %%
dfJugadores.columns
# Out:
# Index(['jugador', 'altura', 'goles'], dtype='object')

# %% [markdown]
# # como leer archivos tipos CSV Y JSON

# %%
import pandas as pd

# %%
df_books=pd.read_csv('./bestsellers-with-categories.csv',header=0,names=['nombre','autor','usurio','reseñas','precio','año','genero'])
#sep -> podemos poner el indentificador
#header->encabezado
#cambiar los nombresde los encabezados

# %%
df_books.columns
# Out:
# Index(['nombre', 'autor', 'usurio', 'resenias', 'precio', 'anio', 'genero'], dtype='object')

# %%
df_books
# Out:
#                                                 nombre  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                         autor  usurio  reseñas  precio   año       genero
# 0                    JJ Smith     4.7    17350       8  2016  Non Fiction
# 1                Stephen King     4.6     2052      22  2011      Fiction
# 2          Jordan B. Peterson     4.7    18979      15  2018  Non Fiction
# ...

# %%
pd.read_json('./hpcharactersdataraw_3d934e85-dfa4-42ec-8520-fadfbecae574.json',typ='Series')
# Out:
# 0       {'Name': 'Mrs. Abbott', 'Link': 'https://www.h...
# 1       {'Name': 'Hannah Abbott', 'Link': 'https://www...
# 2       {'Name': 'Abel Treetops', 'Link': 'https://www...
# 3       {'Name': 'Euan Abercrombie', 'Link': 'https://...
# 4       {'Name': 'Aberforth Dumbledore', 'Link': 'http...
#                               ...
# 1935    {'Name': 'Georgi Zdravko', 'Link': 'https://ww...
# 1936    {'Name': 'Zograf', 'Link': 'https://www.hp-lex...
# 1937    {'Name': 'Zonko', 'Link': 'https://www.hp-lexi...
# 1938    {'Name': 'Valentina Vázquez', 'Link': 'https:/...
# 1939    {'Name': 'Zygmunt Budge', 'Link': 'https://www...
# Length: 1940, dtype: object

# %%
import pandas as pd

# %%
df_books[0:4]
# Out:
#                                     nombre               autor  usurio  \
# 0            10-Day Green Smoothie Cleanse            JJ Smith     4.7
# 1                        11/22/63: A Novel        Stephen King     4.6
# 2  12 Rules for Life: An Antidote to Chaos  Jordan B. Peterson     4.7
# 3                   1984 (Signet Classics)       George Orwell     4.7
#
#    reseñas  precio   año       genero
# 0    17350       8  2016  Non Fiction
# 1     2052      22  2011      Fiction
# 2    18979      15  2018  Non Fiction
# 3    21424       6  2017      Fiction

# %%
df_books[['nombre','autor']]
# Out:
#                                                 nombre  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                         autor
# 0                    JJ Smith
# 1                Stephen King
# 2          Jordan B. Peterson
# 3               George Orwell
# 4    National Geographic Kids
# ..                        ...
# 545               Jeff Kinney
# 546               Jen Sincero
# ...

# %% [markdown]
# loc
# - label

# %%
df_books.loc[0:4,['nombre','autor']]
# Out:
#                                               nombre                     autor
# 0                      10-Day Green Smoothie Cleanse                  JJ Smith
# 1                                  11/22/63: A Novel              Stephen King
# 2            12 Rules for Life: An Antidote to Chaos        Jordan B. Peterson
# 3                             1984 (Signet Classics)             George Orwell
# 4  5,000 Awesome Facts (About Everything!) (Natio...  National Geographic Kids

# %%
df_books.loc[:,['reseñas']]*-1
# Out:
#      reseñas
# 0     -17350
# 1      -2052
# 2     -18979
# 3     -21424
# 4      -7665
# ..       ...
# 545    -9413
# 546   -14331
# 547   -14331
# 548   -14331
# 549   -14331
#
# [550 rows x 1 columns]

# %%
df_books.loc[:,['autor']]=='JJ Smith'
# Out:
#      autor
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# ..     ...
# 545  False
# 546  False
# 547  False
# 548  False
# 549  False
#
# [550 rows x 1 columns]

# %% [markdown]
# ### ILOC

# %% [markdown]
# OO SE PUEDE NAVEGAR MAS RAPIDO POR UN DF

# %%
df_books.iloc[:]
# Out:
#                                                 nombre  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                         autor  usurio  reseñas  precio   año       genero
# 0                    JJ Smith     4.7    17350       8  2016  Non Fiction
# 1                Stephen King     4.6     2052      22  2011      Fiction
# 2          Jordan B. Peterson     4.7    18979      15  2018  Non Fiction
# ...

# %%
df_books.iloc[:,0:3]
# Out:
#                                                 nombre  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                         autor  usurio
# 0                    JJ Smith     4.7
# 1                Stephen King     4.6
# 2          Jordan B. Peterson     4.7
# 3               George Orwell     4.7
# 4    National Geographic Kids     4.8
# ..                        ...     ...
# ...

# %%
df_books.iloc[1,3]*-1
# Out:
# -2052

# %% [markdown]
# ## 15. COMO ELIMNAR DATOS EN PANDAS

# %% [markdown]
# - borrando de la salida

# %% [markdown]
# NOTA
# 0 -> FILAS
# 1 -> COLUMNAS

# %%
#BORRANDO EN LA SALIDA 
df_books.drop('genero',axis=1).head(2)
# Out:
#                           nombre         autor  usurio  reseñas  precio   año
# 0  10-Day Green Smoothie Cleanse      JJ Smith     4.7    17350       8  2016
# 1              11/22/63: A Novel  Stephen King     4.6     2052      22  2011

# %% [markdown]
# elimando desde raiz😬

# %%
df_books.drop('año',axis=1,inplace=True)

# %%
df_books=df_books.drop('genero',axis=1)

# %%
df_books
# Out:
#                                                 nombre  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                         autor  usurio  reseñas  precio
# 0                    JJ Smith     4.7    17350       8
# 1                Stephen King     4.6     2052      22
# 2          Jordan B. Peterson     4.7    18979      15
# 3               George Orwell     4.7    21424       6
# ...

# %% [markdown]
# - funcion de python

# %%
del df_books['genero']

# %% [markdown]
# como borrar filas

# %%
df_books.drop([0,1,2],axis=0).head(2)
# Out:
#                                               nombre  \
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                       autor  usurio  reseñas  precio
# 3             George Orwell     4.7    21424       6
# 4  National Geographic Kids     4.8     7665      12

# %% [markdown]
# ## 16. como manejar datos nulos

# %%
import pandas as pd
import numpy as np

# %%
dict= {'col1':[1,2,3,np.nan],
'col2':[4,np.nan,6,7],
'col2':['a','b','c',None]}

# %%
df=pd.DataFrame(dict)

# %%
df
# Out:
#    col1  col2
# 0   1.0     a
# 1   2.0     b
# 2   3.0     c
# 3   NaN  None

# %%
df.isnull()==1
# Out:
#     col1   col2
# 0  False  False
# 1  False  False
# 2  False  False
# 3   True   True

# %% [markdown]
# 17. como cambiar los datos nulos

# %%
df.fillna('jhon')
# Out:
#    col1  col2
# 0   1.0     a
# 1   2.0     b
# 2   3.0     c
# 3  jhon  jhon

# %%
df.fillna(df.mean())
# Out:
# C:\Users\jhon.velasque\AppData\Local\Temp\ipykernel_6468\634187881.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.fillna(df.mean())
#    col1  col2
# 0   1.0     a
# 1   2.0     b
# 2   3.0     c
# 3   2.0  None

# %%
#este tipo de llenado se usa si sigue una serie 
df.interpolate()
# Out:
#    col1  col2
# 0   1.0     a
# 1   2.0     b
# 2   3.0     c
# 3   3.0  None

# %%
#la forma mas importante
df.dropna()
# Out:
#    col1 col2
# 0   1.0    a
# 1   2.0    b
# 2   3.0    c

# %%
df.fillna(df.mean())
# Out:
# C:\Users\jhon.velasque\AppData\Local\Temp\ipykernel_12964\634187881.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.fillna(df.mean())
#    col1  col2
# 0   1.0     a
# 1   2.0     b
# 2   3.0     c
# 3   2.0  None

# %%
df.fillna(df.min())
# Out:
# C:\Users\jhon.velasque\AppData\Local\Temp\ipykernel_12964\3751672536.py:1: FutureWarning: The default value of numeric_only in DataFrame.min is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.fillna(df.min())
#    col1  col2
# 0   1.0     a
# 1   2.0     b
# 2   3.0     c
# 3   1.0  None

# %% [markdown]
# ## 18. filtrado por condiciones

# %%
import pandas as pd

# %%
df_book=pd.read_csv('./bestsellers-with-categories.csv',sep=',',header=0)

# %%
df_book.head(1)
# Out:
#                             Name    Author  User Rating  Reviews  Price  Year  \
# 0  10-Day Green Smoothie Cleanse  JJ Smith          4.7    17350      8  2016
#
#          Genre
# 0  Non Fiction

# %%
mayor_a_2016=df_book['Year']>2016

# %%
df_book[mayor_a_2016]
# Out:
#                                                   Name  \
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# 7                       A Gentleman in Moscow: A Novel
# 8        A Higher Loyalty: Truth, Lies, and Leadership
# ..                                                 ...
# 544                                             Wonder
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 2          Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3               George Orwell          4.7    21424      6  2017      Fiction
# ...

# %%
df_book[df_book['Year']>2016]
# Out:
#                                                   Name  \
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# 7                       A Gentleman in Moscow: A Novel
# 8        A Higher Loyalty: Truth, Lies, and Leadership
# ..                                                 ...
# 544                                             Wonder
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 2          Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3               George Orwell          4.7    21424      6  2017      Fiction
# ...

# %%
genero_ficcion=df_book['Genre']=='Fiction'

# %%
df_book[mayor_a_2016 & genero_ficcion]
# Out:
#                                                   Name             Author  \
# 3                               1984 (Signet Classics)      George Orwell
# 7                       A Gentleman in Moscow: A Novel        Amor Towles
# 10                           A Man Called Ove: A Novel    Fredrik Backman
# 13                    A Wrinkle in Time (Time Quintet)  Madeleine L'Engle
# 40            Brown Bear, Brown Bear, What Do You See?    Bill Martin Jr.
# ..                                                 ...                ...
# 509                              To Kill a Mockingbird         Harper Lee
# 529  What Should Danny Do? (The Power to Choose Ser...          Adir Levy
# 534                            Where the Crawdads Sing        Delia Owens
# 544                                             Wonder      R. J. Palacio
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)        Jeff Kinney
#
#      User Rating  Reviews  Price  Year    Genre
# ...

# %%
df_book[~mayor_a_2016 & genero_ficcion]
# Out:
#                                                   Name               Author  \
# 1                                    11/22/63: A Novel         Stephen King
# 5        A Dance with Dragons (A Song of Ice and Fire)  George R. R. Martin
# 6    A Game of Thrones / A Clash of Kings / A Storm...  George R. R. Martin
# 9                            A Man Called Ove: A Novel      Fredrik Backman
# 20                         All the Light We Cannot See        Anthony Doerr
# ..                                                 ...                  ...
# 538  Winter of the World: Book Two of the Century T...          Ken Follett
# 540                                             Wonder        R. J. Palacio
# 541                                             Wonder        R. J. Palacio
# 542                                             Wonder        R. J. Palacio
# 543                                             Wonder        R. J. Palacio
#
#      User Rating  Reviews  Price  Year    Genre
# ...

# %% [markdown]
# ## 19. Funciones principales de  pandas

# %% [markdown]
# 1. como conocer mi data set importado?

# %%
df_book.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 df_book.info()
#
# NameError: name 'df_book' is not defined

# %% [markdown]
# 2. como traer los primeros datos de un data set

# %%
df_book.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %% [markdown]
# 3. como traer los datos estadisticos descriptivos principales

# %%
df_book.describe()
# Out:
#        User Rating       Reviews       Price         Year
# count   550.000000    550.000000  550.000000   550.000000
# mean      4.618364  11953.281818   13.100000  2014.000000
# std       0.226980  11731.132017   10.842262     3.165156
# min       3.300000     37.000000    0.000000  2009.000000
# 25%       4.500000   4058.000000    7.000000  2011.000000
# 50%       4.700000   8580.000000   11.000000  2014.000000
# 75%       4.800000  17253.250000   16.000000  2017.000000
# max       4.900000  87841.000000  105.000000  2019.000000

# %% [markdown]
# 4.  como tener los ultimos registros

# %%
df_book.tail()
# Out:
#                                                   Name       Author  \
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)  Jeff Kinney
# 546  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 547  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 548  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 549  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
#
#      User Rating  Reviews  Price  Year        Genre
# 545          4.9     9413      8  2019      Fiction
# 546          4.7    14331      8  2016  Non Fiction
# 547          4.7    14331      8  2017  Non Fiction
# 548          4.7    14331      8  2018  Non Fiction
# 549          4.7    14331      8  2019  Non Fiction

# %% [markdown]
# 5. como saber cuanta memoria esta usando el data set

# %%
df_book.memory_usage(deep=True)
# Out:
# Index            128
# Name           59737
# Author         39078
# User Rating     4400
# Reviews         4400
# Price           4400
# Year            4400
# Genre          36440
# dtype: int64

# %% [markdown]
# 6. como contar los valores condicionados

# %%
df_book['Year'].value_counts()
# Out:
# 2016    50
# 2011    50
# 2018    50
# 2017    50
# 2019    50
# 2014    50
# 2010    50
# 2009    50
# 2015    50
# 2013    50
# 2012    50
# Name: Year, dtype: int64

# %% [markdown]
# 7. como limpiar nuestro data set

# %%
df_book.iloc[0]
# Out:
# Name           10-Day Green Smoothie Cleanse
# Author                              JJ Smith
# User Rating                              4.7
# Reviews                                17350
# Price                                      8
# Year                                    2016
# Genre                            Non Fiction
# Name: 0, dtype: object

# %%
df_book=df_book.append(df_book.iloc[0])
# Out:
# C:\Users\jhon.velasque\AppData\Local\Temp\ipykernel_12964\4015149275.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_book=df_book.append(df_book.iloc[0])

# %%
df_book
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
# 0                        10-Day Green Smoothie Cleanse
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
# elimando datos duplicados
df_book.drop_duplicates(keep='last')
#con esto mantenemos el ultimo
# Out:
#                                                   Name  \
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# 5        A Dance with Dragons (A Song of Ice and Fire)
# ..                                                 ...
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
# 0                        10-Day Green Smoothie Cleanse
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 1                Stephen King          4.6     2052     22  2011      Fiction
# 2          Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# ...

# %% [markdown]
# 8. como ordenar nuestro data set

# %%
df_book.sort_values('Year',ascending=False)
# Out:
#                                                   Name                 Author  \
# 179                       If Animals Kissed Good Night      Ann Whitford Paul
# 294  School Zone - Big Preschool Workbook - Ages 4 ...            School Zone
# 263    P is for Potty! (Sesame Street) (Lift-the-Flap)        Naomi Kleinberg
# 489                   The Wonderful Things You Will Be  Emily Winfield Martin
# 267             Player's Handbook (Dungeons & Dragons)       Wizards RPG Team
# ..                                                 ...                    ...
# 160                  Have a Little Faith: A True Story            Mitch Albom
# 512                             True Compass: A Memoir      Edward M. Kennedy
# 513               Twilight (The Twilight Saga, Book 1)        Stephenie Meyer
# 78   Divine Soul Mind Body Healing and Transmission...           Zhi Gang Sha
# 459        The Shack: Where Tragedy Confronts Eternity       William P. Young
#
# ...

# %%
df_book.groupby('Genre').size()
# Out:
# Genre
# Fiction        240
# Non Fiction    311
# dtype: int64

# %% [markdown]
# ## 20. GROUPBY

# %% [markdown]
# 1. COMO HACER TU PRIMER AGRUPAMIENTO

# %%
df_book.groupby('Author').count()
# Out:
#                             Name  User Rating  Reviews  Price  Year  Genre
# Author
# Abraham Verghese               2            2        2      2     2      2
# Adam Gasiewski                 1            1        1      1     1      1
# Adam Mansbach                  1            1        1      1     1      1
# Adir Levy                      1            1        1      1     1      1
# Admiral William H. McRaven     1            1        1      1     1      1
# ...                          ...          ...      ...    ...   ...    ...
# Walter Isaacson                3            3        3      3     3      3
# William Davis                  2            2        2      2     2      2
# William P. Young               2            2        2      2     2      2
# Wizards RPG Team               3            3        3      3     3      3
# Zhi Gang Sha                   2            2        2      2     2      2
#
# [248 rows x 6 columns]

# %%
df_book.groupby('Author').count().loc['William Davis']
# Out:
# Name           2
# User Rating    2
# Reviews        2
# Price          2
# Year           2
# Genre          2
# Name: William Davis, dtype: int64

# %% [markdown]
# 📚sacando los autores de inide

# %%
df_book.groupby('Author').sum().reset_index()
# Out:
# C:\Users\jhon.velasque\AppData\Local\Temp\ipykernel_12964\2996270666.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_book.groupby('Author').sum().reset_index()
#                          Author  User Rating  Reviews  Price  Year
# 0              Abraham Verghese          9.2     9732     22  4021
# 1                Adam Gasiewski          4.4     3113      6  2017
# 2                 Adam Mansbach          4.8     9568      9  2011
# 3                     Adir Levy          4.8     8170     13  2019
# 4    Admiral William H. McRaven          4.7    10199     11  2017
# ..                          ...          ...      ...    ...   ...
# 243             Walter Isaacson         13.7    18668     61  6040
# 244               William Davis          8.8    14994     12  4025
# ...

# %%
df_book.groupby('Author').agg({'Reviews':['min','max'],'User Rating':'sum'})
# Out:
#                            Reviews        User Rating
#                                min    max         sum
# Author
# Abraham Verghese              4866   4866         9.2
# Adam Gasiewski                3113   3113         4.4
# Adam Mansbach                 9568   9568         4.8
# Adir Levy                     8170   8170         4.8
# Admiral William H. McRaven   10199  10199         4.7
# ...                            ...    ...         ...
# Walter Isaacson               3014   7827        13.7
# William Davis                 7497   7497         8.8
# William P. Young             19720  19720         9.2
# Wizards RPG Team             16990  16990        14.4
# Zhi Gang Sha                    37    220         9.2
#
# [248 rows x 3 columns]

# %%
df_book.groupby(['Author','Year']).count()
# Out:
#                        Name  User Rating  Reviews  Price  Genre
# Author           Year
# Abraham Verghese 2010     1            1        1      1      1
#                  2011     1            1        1      1      1
# Adam Gasiewski   2017     1            1        1      1      1
# Adam Mansbach    2011     1            1        1      1      1
# Adir Levy        2019     1            1        1      1      1
# ...                     ...          ...      ...    ...    ...
# Wizards RPG Team 2017     1            1        1      1      1
#                  2018     1            1        1      1      1
#                  2019     1            1        1      1      1
# Zhi Gang Sha     2009     1            1        1      1      1
#                  2013     1            1        1      1      1
#
# [493 rows x 5 columns]

# %% [markdown]
# ## 21. Combiando Data Frame

# %%
df1=pd.DataFrame({'A':['A0','A1','A2','A3','A4','A5','A6'],
'B':['B0','B1','B2','B3','B4','B5','B6'],
'C':['C0','C1','C2','C3','C4','C5','C6'],
'D':['D0','D1','D2','D3','D4','D5','D6']})
df2=pd.DataFrame({'A':['A7','A8','A9','A10','A11','A12','A13'],
'B':['B7','B8','B9','B10','B11','B12','B13'],
'C':['C7','C8','C9','C10','C11','C12','C13'],
'D':['D7','D8','D9','D10','D11','D12','D13']})

# %%
pd.concat([df1,df2], ignore_index=True)
#la funcion ignoore hace corregir el index despues de unir los df
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11
# 12  A12  B12  C12  D12
# 13  A13  B13  C13  D13

# %%
pd.concat([df1,df2], ignore_index=True,axis=1)
# Out:
#     0   1   2   3    4    5    6    7
# 0  A0  B0  C0  D0   A7   B7   C7   D7
# 1  A1  B1  C1  D1   A8   B8   C8   D8
# 2  A2  B2  C2  D2   A9   B9   C9   D9
# 3  A3  B3  C3  D3  A10  B10  C10  D10
# 4  A4  B4  C4  D4  A11  B11  C11  D11
# 5  A5  B5  C5  D5  A12  B12  C12  D12
# 6  A6  B6  C6  D6  A13  B13  C13  D13

# %% [markdown]
# 2. aprendiendo merge

# %%
left = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                     'A': ['A0', 'A1', 'A2', 'A3'],
                     'B': ['B0', 'B1', 'B2', 'B3']})
   
right = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                          'C': ['C0', 'C1', 'C2', 'C3'],
                          'D': ['D0', 'D1', 'D2', 'D3']})    

print(left, "\n\n", right)
# Out:
#   key   A   B
# 0  K0  A0  B0
# 1  K1  A1  B1
# 2  K2  A2  B2
# 3  K3  A3  B3
#
#    key   C   D
# 0  K0  C0  D0
# 1  K1  C1  D1
# 2  K2  C2  D2
# 3  K3  C3  D3

# %%
left.merge(right,on='key')
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K1  A1  B1  C1  D1
# 2  K2  A2  B2  C2  D2
# 3  K3  A3  B3  C3  D3

# %%
left1 = pd.DataFrame({'key2': ['K0', 'K1', 'K2', 'K3'],
                     'A': ['A0', 'A1', 'A2', 'A3'],
                     'B': ['B0', 'B1', 'B2', 'B3']})
   
right2 = pd.DataFrame({'key1': ['K0', 'K1', 'K2', 'None'],
                          'C': ['C0', 'C1', 'C2', 'C3'],
                          'D': ['D0', 'D1', 'D2', 'D3']})    

print(left, "\n\n", right)
# Out:
#   key   A   B
# 0  K0  A0  B0
# 1  K1  A1  B1
# 2  K2  A2  B2
# 3  K3  A3  B3
#
#    key   C   D
# 0  K0  C0  D0
# 1  K1  C1  D1
# 2  K2  C2  D2
# 3  K3  C3  D3

# %% [markdown]
# - importante como usar merge  con distitas llaves

# %%
left1.merge(right2,left_on='key2',right_on='key1')
# Out:
#   key2   A   B key1   C   D
# 0   K0  A0  B0   K0  C0  D0
# 1   K1  A1  B1   K1  C1  D1
# 2   K2  A2  B2   K2  C2  D2

# %%
left
# Out:
#   key   A   B
# 0  K0  A0  B0
# 1  K1  A1  B1
# 2  K2  A2  B2
# 3  K3  A3  B3

# %% [markdown]
# - como usarlos tipos de merge

# %%
left1.merge(right2,left_on='key2',right_on='key1',how='outer')
# Out:
#   key2    A    B  key1    C    D
# 0   K0   A0   B0    K0   C0   D0
# 1   K1   A1   B1    K1   C1   D1
# 2   K2   A2   B2    K2   C2   D2
# 3   K3   A3   B3   NaN  NaN  NaN
# 4  NaN  NaN  NaN  None   C3   D3

# %% [markdown]
# ## Como usar el comando join

# %% [markdown]
# - join trabaja con indices

# %%
l = pd.DataFrame({
                     'A': ['A0', 'A1', 'A2', 'A3'],
                     'B': ['B0', 'B1', 'B2', 'B3']},
                     index = ['K0', 'K1', 'K2', 'K3'])
   
r = pd.DataFrame({ 'C': ['C0', 'C1', 'C2', 'C3'],
                        'D': ['D0', 'D1', 'D2', 'D3']},
                    index = ['K0', 'K1', 'K2', 'K3'])    

print(left, "\n\n", right)
# Out:
#      A   B
# K0  A0  B0
# K1  A1  B1
# K2  A2  B2
# K3  A3  B3
#
#       C   D
# K0  C0  D0
# K1  C1  D1
# K2  C2  D2
# K3  C3  D3

# %%
l.join(r)
# Out:
#      A   B   C   D
# K0  A0  B0  C0  D0
# K1  A1  B1  C1  D1
# K2  A2  B2  C2  D2
# K3  A3  B3  C3  D3

# %% [markdown]
# ## Pivot y Melt

# %%
df_books = pd.read_csv('./bestsellers-with-categories.csv',sep=',',header=0)

# %%
df_books.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
df_books.pivot_table(index='Author',columns='Genre',values='User Rating')
# Out:
# Genre                       Fiction  Non Fiction
# Author
# Abraham Verghese                4.6          NaN
# Adam Gasiewski                  NaN     4.400000
# Adam Mansbach                   4.8          NaN
# Adir Levy                       4.8          NaN
# Admiral William H. McRaven      NaN     4.700000
# ...                             ...          ...
# Walter Isaacson                 NaN     4.566667
# William Davis                   NaN     4.400000
# William P. Young                4.6          NaN
# Wizards RPG Team                4.8          NaN
# Zhi Gang Sha                    NaN     4.600000
#
# [248 rows x 2 columns]

# %% [markdown]
# ## 24.

# %%
df_books.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
#mi primera funcion de phython
def two_times(values):
    return values*2

# %%
df_books['Rating 2']=df_books['User Rating'].apply(two_times)

# %%
df_books['Rating **']=df_books['User Rating'].apply(lambda x:x*x)

# %%
df_books
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre  \
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
df_books.apply(lambda x:x['User Rating']*2 if x['Genre']=='fiction' else x['User Rating'],axis=1)
# Out:
# 0      4.7
# 1      4.6
# 2      4.7
# 3      4.7
# 4      4.8
#       ...
# 545    4.9
# 546    4.7
# 547    4.7
# 548    4.7
# 549    4.7
# Length: 550, dtype: float64
